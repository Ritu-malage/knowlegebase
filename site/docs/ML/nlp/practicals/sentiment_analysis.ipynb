# %% [markdown]
# # Sentiment Analysis
# - Problem statement: Given the reviews of the resturants, determine whether the review is positive or negative

# %%
import pandas as pd

df = pd.read_csv("../datasets/Restaurant_Reviews.tsv", delimiter="\t", quoting = 3)
df
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %% [markdown]
# - quoting = 3 is used to ignore the double quotes present in the question

# %% [markdown]
# # Cleaning of text
#
# - Remove stopwords as they dont determine whether the review is positive or negative

# %%
import re
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ritumalage/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 5
#       1 import re
#       2 import nltk
#       3 nltk.download("stopwords")
#       4 from nltk.corpus import stopwords
# ----> 5 from ntlk.stem.porter import PorterStemmer
#
# ModuleNotFoundError: No module named 'ntlk'

# %%
import os
os.listdir("../datasets")
# Out:
# ['Restaurant_Reviews.tsv']
